# %% [markdown]
# <a href="https://colab.research.google.com/github/Tylersuard/SarcasmGenerator/blob/main/A_I_Sarcastic_Headline_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# How to use:
# 1. click "Runtime" menu above
# 2. click "Change runtime type"
# 3. Select "GPU"
# 4. Click OK
# 5. Click "Runtime" menu again
# 6. Click "Run All"
# 7. Scroll down.  The notebook should start outputting sarcastic titles in a few minutes.

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip3 install gpt-2-simple
# Out:
# ...
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.1-cp36-none-any.whl size=23580 sha256=f59e312df6b8aa0294f0797529788c226eaead3402861b6ee5acb5eafaf77d9a
#   Stored in directory: /root/.cache/pip/wheels/0c/f8/23/b53ce437504597edff76bf9c3b8de08ad716f74f6c6baaa91a
# Successfully built gpt-2-simple
# ...

# %%
# !gdown https://drive.google.com/uc?id=1gqg9pAZVecGt_Jl5F3Hnd1XbqnjiWJ6W
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gqg9pAZVecGt_Jl5F3Hnd1XbqnjiWJ6W
# To: /content/Sarcasm_dataset_filtered2.txt
# 100% 921k/921k [00:00<00:00, 61.3MB/s]

# %%
import gpt_2_simple as gpt2
import os
import requests

model_name = "345M"
if not os.path.isdir(os.path.join("models", model_name)):
	print(f"Downloading {model_name} model...")
	gpt2.download_gpt2(model_name=model_name)   


file_name = "/content/Sarcasm_dataset_filtered2.txt"
"""
if not os.path.isfile(file_name):
	url = "/content/dostoyevsky.txt" #  <--- Change this to the name of the text file you want to train GPT-2 with
	data = url
	
	with open(file_name, 'w') as f:
		f.write(data)
""" 

sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              file_name,
              model_name=model_name,
              steps=200)   # steps is max number of training steps

gpt2.generate(sess)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
# Fetching checkpoint: 1.05Mit [00:00, 320Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 88.8Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 636Mit/s]
# ...
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:05, 238Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 472Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 115Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 188Mit/s]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
#Run this command to generate more text from your last training session
for i in range(0,5):
  gpt2.generate(sess)
# Out:
# jim ryan dies at 96"
# andrew mccabe reaches out to all the other americans to see what's wrong with them
# santorum signs on as prez
# "new yorkers assure christopher kavanaugh they have nothing on you, either"
# report: man's best friend really just a shitty friend
# laura drummond reflects on leaving husband
# mike pence holds a press conference to announce unborn baby is dead
# new political science explores the role of money in our elections
# "ben carter admits to abusing children, too"
# david williams makes good porn
# arabesque community to spread god's love
# trump campaign touts job creation
# "obesity epidemic beginning to catch up to americans"
# "third-grader 'fucking whatever' says what was supposed to be a boring story about how trump got down on all fours and kissed paula"
# gop takes back control of congress
# "report: highest aunt burned down in fire"
# laura drummond exhausted from all the ramen
# gop approves $20 billion war on drugs
# ...
